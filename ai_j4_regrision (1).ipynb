# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn import linear_model
import sklearn.metrics as sm
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('co2.csv')

# %%
df.describe()
# Out:
#            engine     cylandr    fuelcomb        out1
# count  500.000000  500.000000  500.000000  500.000000
# mean     3.600400    6.132000   12.476600  268.026000
# std      1.478191    1.832291    3.943025   67.099673
# min      1.000000    4.000000    4.800000  110.000000
# 25%      2.000000    4.000000    9.500000  217.000000
# 50%      3.600000    6.000000   11.650000  260.000000
# 75%      5.000000    8.000000   14.800000  317.000000
# max      6.800000   12.000000   25.800000  488.000000

# %%
sns.countplot(x='out1',data=df)
# Out:
# <Axes: xlabel='out1', ylabel='count'>

# %%
plt.subplots(figsize=(9,9))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
x=df.drop("out1",axis=1)
x=x.drop("fuelcomb", axis=1)
x=x.drop("cylandr",axis=1)
y=df.out1

# %%
x
# Out:
#      engine
# 0       2.0
# 1       2.4
# 2       1.5
# 3       3.5
# 4       3.5
# ..      ...
# 495     1.5
# 496     1.5
# 497     1.5
# 498     3.5
# 499     3.6
#
# [500 rows x 1 columns]

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.2)

# %%
X_train
# Out:
#      engine
# 357     2.0
# 198     1.4
# 275     2.4
# 157     2.0
# 265     5.3
# ..      ...
# 205     3.6
# 35      4.0
# 493     2.4
# 14      5.9
# 188     3.6
#
# [400 rows x 1 columns]

# %%
X_test
# Out:
#      engine
# 347     4.6
# 164     2.0
# 334     1.4
# 212     5.3
# 490     1.8
# ..      ...
# 45      4.2
# 321     1.4
# 33      3.0
# 287     3.6
# 373     3.5
#
# [100 rows x 1 columns]

# %%
reg_linear=linear_model.LinearRegression()

# %%
reg_linear.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_test_pred=reg_linear.predict(X_test)

# %%
Y_test_pred
# Out:
# array([308.59349803, 205.30479867, 181.46894497, 336.40199402,
#        197.3595141 , 268.8670752 , 336.40199402, 264.89443292,
#        268.8670752 , 364.21049   , 189.41422953, 173.5236604 ,
#        372.15577457, 284.75764433, 268.8670752 , 380.10105914,
#        205.30479867, 205.30479867, 268.8670752 , 221.1953678 ,
#        372.15577457, 268.8670752 , 372.15577457, 268.8670752 ,
#        197.3595141 , 268.8670752 , 292.7029289 , 205.30479867,
#        197.3595141 , 181.46894497, 205.30479867, 205.30479867,
#        264.89443292, 245.0312215 , 352.29256315, 312.56614032,
#        181.46894497, 205.30479867, 245.0312215 , 245.0312215 ,
#        268.8670752 , 268.8670752 , 205.30479867, 221.1953678 ,
#        205.30479867, 268.8670752 , 268.8670752 , 268.8670752 ,
#        221.1953678 , 364.21049   , 268.8670752 , 264.89443292,
#        245.0312215 , 197.3595141 , 268.8670752 , 205.30479867,
#        205.30479867, 221.1953678 , 221.1953678 , 264.89443292,
#        316.5387826 , 364.21049   , 376.12841685, 372.15577457,
#        336.40199402, 336.40199402, 324.48406717, 268.8670752 ,
#        300.64821347, 336.40199402, 205.30479867, 205.30479867,
#        336.40199402, 205.30479867, 205.30479867, 268.8670752 ,
#        245.0312215 , 340.3746363 , 352.29256315, 264.89443292,
#        225.16801008, 268.8670752 , 364.21049   , 268.8670752 ,
#        205.30479867, 221.1953678 , 189.41422953, 189.41422953,
#        268.8670752 , 264.89443292, 272.83971748, 205.30479867,
#        245.0312215 , 352.29256315, 268.8670752 , 292.7029289 ,
#        181.46894497, 245.0312215 , 268.8670752 , 264.89443292])

# %%
Y_test
# Out:
# 347    386
# 164    232
# 334    182
# 212    334
# 490    175
#       ...
# 45     336
# 321    168
# 33     224
# 287    237
# 373    308
# Name: out1, Length: 100, dtype: int64

# %%
X_test
# Out:
#      engine
# 347     4.6
# 164     2.0
# 334     1.4
# 212     5.3
# 490     1.8
# ..      ...
# 45      4.2
# 321     1.4
# 33      3.0
# 287     3.6
# 373     3.5
#
# [100 rows x 1 columns]

# %%
plt.scatter(X_test,Y_test,color='red')
plt.show()

# %%
plt.scatter(X_test,Y_test,color='red')
plt.plot(X_test,Y_test_pred,color='black',linewidth=2)
plt.show()

# %%
new_var = 1.36
p206=np.array([[new_var]])

# %%
co2=reg_linear.predict(p206)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
co2
# Out:
# array([179.87988805])
